# %%
# prompt: read the data.xlsx and show data properties

import pandas as pd
df = pd.read_excel('data.xlsx')
df.describe()
# Out:
# Running cells with 'Python 3.12.2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/local/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# prompt: df

df
# Out:
#     Unnamed: 0           Unnamed: 1   Unnamed: 2    Unnamed: 3
# 0           ID                 Date  Log in time  Log Out Time
# 1        30315  2024-08-11 00:00:00     21:57:54           NaN
# 2        30311  2024-08-11 00:00:00     21:49:59           NaN
# 3        30107  2024-08-11 00:00:00     21:40:51           NaN
# 4        30333  2024-08-11 00:00:00     21:34:37           NaN
# ..         ...                  ...          ...           ...
# 643      30279  2024-08-11 00:00:00     00:28:14           NaN
# 644      10226  2024-08-11 00:00:00     00:25:01           NaN
# 645      30377  2024-08-11 00:00:00     00:14:59           NaN
# 646      30361  2024-08-11 00:00:00     00:12:13           NaN
# 647      30361  2024-08-11 00:00:00     00:07:02           NaN
#
# [648 rows x 4 columns]

# %%
# prompt: rename all the column alphapheticaly like A,B,C,D

import pandas as pd

# !pip install pandas
df = pd.read_excel('data.xlsx')
df.describe()

new_columns = [chr(ord('A') + i) for i in range(len(df.columns))]
df.columns = new_columns

df
# Out:
# ...
#          A                    B            C             D
# 0       ID                 Date  Log in time  Log Out Time
# 1    30315  2024-08-11 00:00:00     21:57:54           NaN
# 2    30311  2024-08-11 00:00:00     21:49:59           NaN
# 3    30107  2024-08-11 00:00:00     21:40:51           NaN
# 4    30333  2024-08-11 00:00:00     21:34:37           NaN
# ..     ...                  ...          ...           ...
# 643  30279  2024-08-11 00:00:00     00:28:14           NaN
# 644  10226  2024-08-11 00:00:00     00:25:01           NaN
# 645  30377  2024-08-11 00:00:00     00:14:59           NaN
# 646  30361  2024-08-11 00:00:00     00:12:13           NaN
# 647  30361  2024-08-11 00:00:00     00:07:02           NaN
#
# [648 rows x 4 columns]

# %%
df = df.iloc[1:]

# %%
print(df.columns)
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df
# Out:
#          A                    B         C    D
# 1    30315  2024-08-11 00:00:00  21:57:54  NaN
# 2    30311  2024-08-11 00:00:00  21:49:59  NaN
# 3    30107  2024-08-11 00:00:00  21:40:51  NaN
# 4    30333  2024-08-11 00:00:00  21:34:37  NaN
# 5    30297  2024-08-11 00:00:00  21:34:07  NaN
# ..     ...                  ...       ...  ...
# 643  30279  2024-08-11 00:00:00  00:28:14  NaN
# 644  10226  2024-08-11 00:00:00  00:25:01  NaN
# 645  30377  2024-08-11 00:00:00  00:14:59  NaN
# 646  30361  2024-08-11 00:00:00  00:12:13  NaN
# 647  30361  2024-08-11 00:00:00  00:07:02  NaN
#
# [647 rows x 4 columns]

# %%
# prompt: i Want to retrieve  data from this excel.
# Here "A" contains employee id , "B" Contains d/m/y format , "C" contains employees all login time of the day. Each entry represents a single login. one employee logged in multiple times. so the ID column does not contain unique entity. I want to retrieve the data of all employees first and last login time of a day

import pandas as pd

# Assuming 'df' is already loaded as in the preceding code

# Convert column 'B' to datetime objects
df['B'] = pd.to_datetime(df['B'], dayfirst=True)

# Extract date from datetime
df['Date'] = df['B'].dt.date

# Group by employee ID and date to find first and last login times
result = df.groupby(['A', 'Date'])['B'].agg(['min', 'max'])

# Rename columns for clarity
result.columns = ['First Login', 'Last Login']

# Reset index to make 'A' and 'Date' regular columns
result = result.reset_index()

print(result)
# Out:
#          A        Date First Login Last Login
# 0    10008  2024-08-11  2024-08-11 2024-08-11
# 1    10023  2024-08-11  2024-08-11 2024-08-11
# 2    10034  2024-08-11  2024-08-11 2024-08-11
# 3    10065  2024-08-11  2024-08-11 2024-08-11
# 4    10091  2024-08-11  2024-08-11 2024-08-11
# ..     ...         ...         ...        ...
# 113  30392  2024-08-11  2024-08-11 2024-08-11
# 114  30393  2024-08-11  2024-08-11 2024-08-11
# 115  30396  2024-08-11  2024-08-11 2024-08-11
# 116  30397  2024-08-11  2024-08-11 2024-08-11
# 117  30401  2024-08-11  2024-08-11 2024-08-11
#
# [118 rows x 4 columns]
# <ipython-input-13-f33c1dd75317>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['B'] = pd.to_datetime(df['B'], dayfirst=True)
# ...

# %%
# prompt: print result in a text file

with open('result.txt', 'w') as f:
  f.write(result.to_string())
